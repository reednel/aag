# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Get Data

# %%
constant_public = 10
constant_private = 5
public_values = [1,2,3,4,5]
private_values = [1,2,3,4,5]
colors = ['red', 'orange', 'yellow', 'green', 'blue']

# %%
arr = np.loadtxt("heisenberg.csv",
                 delimiter=",", dtype=float)
arr = np.reshape(arr, (-1, 4))
arr = arr[1:, :]
print(arr)
# Out:
# [[9.65878000e+01 2.48429600e+02 5.00000000e+00 1.00000000e+00]
#  [9.77777000e+01 2.30750800e+02 5.00000000e+00 1.00000000e+00]
#  [9.30635000e+01 2.29156300e+02 5.00000000e+00 1.00000000e+00]
#  [9.37748000e+01 2.33628500e+02 5.00000000e+00 2.00000000e+00]
#  [9.44850000e+01 3.97017400e+02 5.00000000e+00 2.00000000e+00]
#  [9.73588000e+01 4.22362100e+02 5.00000000e+00 2.00000000e+00]
#  [9.97058000e+01 1.26375710e+03 5.00000000e+00 3.00000000e+00]
#  [9.79208000e+01 1.22705220e+03 5.00000000e+00 3.00000000e+00]
#  [9.78621000e+01 9.90044600e+02 5.00000000e+00 3.00000000e+00]
#  [9.72719000e+01 2.00846224e+04 5.00000000e+00 4.00000000e+00]
#  [9.57047000e+01 2.16094590e+03 5.00000000e+00 4.00000000e+00]
#  [9.52717000e+01 2.35761560e+03 5.00000000e+00 4.00000000e+00]
#  [1.13579000e+02 8.31876637e+04 5.00000000e+00 5.00000000e+00]
#  [1.05913900e+02 1.94316223e+05 5.00000000e+00 5.00000000e+00]
#  [1.09713700e+02 1.05655214e+05 5.00000000e+00 5.00000000e+00]]

# %%
static_public = arr[np.where(arr[:, 2] == constant_public)]
static_private = arr[np.where(arr[:, 3] == constant_private)]
print(static_public)
print(static_private)
# Out:
# []
# [[1.13579000e+02 8.31876637e+04 5.00000000e+00 5.00000000e+00]
#  [1.05913900e+02 1.94316223e+05 5.00000000e+00 5.00000000e+00]
#  [1.09713700e+02 1.05655214e+05 5.00000000e+00 5.00000000e+00]]

# %%
for i in range(5): 
    tempArr = static_public[np.where(static_public[:, 3] == private_values[i])]
    scatter = plt.scatter(tempArr[:,0], tempArr[:,1], c=colors[i], s = 50, label='Private length:' + str(private_values[i]))
plt.xlabel("Exchange Time (ms)", size=12)
plt.ylabel("Attack Time (ms)", size=12)
plt.title('Public key Held to Size 10', size=20)
plt.legend()
plt.show()

# %%
for i in range(5): 
    tempArr = static_private[np.where(static_private[:, 2] == public_values[i])]
    scatter = plt.scatter(tempArr[:,0], tempArr[:,1], c=colors[i], s = 50, label='Public length:' + str(public_values[i]))
plt.xlabel("Exchange Time (μ)", size=12)
plt.ylabel("Attack Time (μ)", size=12)
plt.title('Private key Held to Size 10', size=20)
plt.legend()
plt.show()
