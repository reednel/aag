# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('permutation_all.csv')
df['attack'] *= 1e-3
df['exchange'] *= 1e-3

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='pk', palette='crest')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df[df['pk']==7], hue='sk', vars=['exchange', 'attack'], palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='pk', vars=['exchange', 'attack'], palette='crest')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.jointplot(data=df, x='exchange', y='attack', hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.jointplot(data=df.query("sk==5"), x='exchange', y='attack', hue='pk', type='sk', palette='flare')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[84], line 2
#       1 sns.set_theme(style="whitegrid")
# ----> 2 gfg = sns.jointplot(data=df.query("sk==5"), x='exchange', y='attack', hue='pk', type='sk', palette='flare')
#       3 plt.show()
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:2255, in jointplot(data, x, y, hue, kind, height, ratio, space, dropna, xlim, ylim, color, palette, hue_order, hue_norm, marginal_ticks, joint_kws, marginal_kws, **kwargs)
#    2252 if kind.startswith("scatter"):
#    2254     joint_kws.setdefault("color", color)
# -> 2255     grid.plot_joint(scatterplot, **joint_kws)
#    2257     if grid.hue is None:
#    2258         marg_func = histplot
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:1826, in JointGrid.plot_joint(self, func, **kwargs)
#    1823     self._inject_kwargs(func, kwargs, self._hue_params)
#    1825 if str(func.__module__).startswith("seaborn"):
# -> 1826     func(x=self.x, y=self.y, **kwargs)
#    1827 else:
#    1828     func(self.x, self.y, **kwargs)
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/relational.py:761, in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     758 color = kwargs.pop("color", None)
#     759 kwargs["color"] = _default_color(ax.scatter, hue, color, kwargs)
# --> 761 p.plot(ax, kwargs)
#     763 return ax
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/relational.py:573, in _ScatterPlotter.plot(self, ax, kws)
#     570     kws.setdefault("edgecolor", "w")
#     572 # Draw the scatter plot
# --> 573 points = ax.scatter(x=x, y=y, **kws)
#     575 # Apply the mapping from semantic variables to artist attributes
#     577 if "hue" in self.variables:
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/__init__.py:1414, in _preprocess_data.<locals>.inner(ax, data, *args, **kwargs)
#    1411 @functools.wraps(func)
#    1412 def inner(ax, *args, data=None, **kwargs):
#    1413     if data is None:
# -> 1414         return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1416     bound = new_sig.bind(ax, *args, **kwargs)
#    1417     auto_label = (bound.arguments.get(label_namer)
#    1418                   or bound.kwargs.get(label_namer))
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/axes/_axes.py:4467, in Axes.scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, edgecolors, plotnonfinite, **kwargs)
#    4457 collection = mcoll.PathCollection(
#    4458         (path,), scales,
#    4459         facecolors=colors,
#    (...)
#    4464         alpha=alpha
#    4465         )
#    4466 collection.set_transform(mtransforms.IdentityTransform())
# -> 4467 collection.update(kwargs)
#    4469 if colors is None:
#    4470     collection.set_array(c)
#
# File /opt/homebrew/lib/python3.10/site-packages/matplotlib/artist.py:1067, in Artist.update(self, props)
#    1065             func = getattr(self, f"set_{k}", None)
#    1066             if not callable(func):
# -> 1067                 raise AttributeError(f"{type(self).__name__!r} object "
#    1068                                      f"has no property {k!r}")
#    1069             ret.append(func(v))
#    1070 if ret:
#
# AttributeError: 'PathCollection' object has no property 'type'

# %%
sns.set_theme(style="whitegrid")
gfg = sns.scatterplot(data=df, x='exchange', y='attack', hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.kdeplot(
   data=df[df['pk']==7], x="attack", hue="sk",
   fill=True, common_norm=False, palette="flare",
   alpha=.5, linewidth=0, log_scale=True
)
gfg.set(title="Attack Time vs Private Key Length", xlabel="Attack Time (ms)")
plt.show()

# %%
sns.set_theme(style="whitegrid")
df2 = df[df['sk'] == 6]
gfg = sns.kdeplot(
   data=df2, x="attack", hue="pk",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0, log_scale=True
)
gfg.set(title="Attack Time vs Public Key Length", xlabel="Attack Time (ms)")
plt.show()

# %%
# heatmap comparing sk and pk effects on attack time
sns.set_theme(style="whitegrid")
df['efficiency'] = df['attack'] / df['exchange']
g = sns.JointGrid(data=df, x="pk", y="sk")
g.plot_joint(sns.scatterplot, c=df["efficiency"], size=df["attack"], sizes=(30,1200), palette="flare", alpha=.6, legend=False)
g.plot_marginals(sns.histplot, color="m", kde=True)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:1826: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=self.x, y=self.y, **kwargs)

# %%
# on the same axes, plot the attack time vs exchange time
sns.set_theme(style="whitegrid")
g = sns.JointGrid(data=df, x="efficiency", y="sk")
g.plot_joint(sns.scatterplot, c=df["efficiency"], size=df["attack"], sizes=(30,1200), palette="flare", alpha=.6, legend=False)
g.plot_marginals(sns.histplot, color="m", kde=True)
plt.show()
# Out:
# /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:1826: UserWarning: Ignoring `palette` because no `hue` variable has been assigned.
#   func(x=self.x, y=self.y, **kwargs)
