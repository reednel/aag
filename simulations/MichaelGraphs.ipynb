# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %%
df = pd.read_csv('all.csv')
df['efficiency'] = df['attack'] / df['exchange']

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='pk', palette='crest')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[81], line 2
#       1 sns.set_theme(style="whitegrid")
# ----> 2 gfg = sns.pairplot(data=df, hue='pk', palette='crest')
#       3 plt.show()
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:2148, in pairplot(data, hue, hue_order, palette, vars, x_vars, y_vars, kind, diag_kind, markers, height, aspect, corner, dropna, plot_kws, diag_kws, grid_kws, size)
#    2146     diag_kws.setdefault("fill", True)
#    2147     diag_kws.setdefault("warn_singular", False)
# -> 2148     grid.map_diag(kdeplot, **diag_kws)
#    2150 # Maybe plot on the off-diagonals
#    2151 if diag_kind is not None:
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/axisgrid.py:1507, in PairGrid.map_diag(self, func, **kwargs)
#    1505     plot_kwargs.setdefault("hue_order", self._hue_order)
#    1506     plot_kwargs.setdefault("palette", self._orig_palette)
# -> 1507     func(x=vector, **plot_kwargs)
#    1508     ax.legend_ = None
#    1510 self._add_axis_labels()
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/distributions.py:1717, in kdeplot(data, x, y, hue, weights, palette, hue_order, hue_norm, color, fill, multiple, common_norm, common_grid, cumulative, bw_method, bw_adjust, warn_singular, log_scale, levels, thresh, gridsize, cut, clip, legend, cbar, cbar_ax, cbar_kws, ax, **kwargs)
#    1713 if p.univariate:
#    1715     plot_kws = kwargs.copy()
# -> 1717     p.plot_univariate_density(
#    1718         multiple=multiple,
#    1719         common_norm=common_norm,
#    1720         common_grid=common_grid,
#    1721         fill=fill,
#    1722         color=color,
#    1723         legend=legend,
#    1724         warn_singular=warn_singular,
#    1725         estimate_kws=estimate_kws,
#    1726         **plot_kws,
#    1727     )
#    1729 else:
#    1731     p.plot_bivariate_density(
#    1732         common_norm=common_norm,
#    1733         fill=fill,
#    (...)
#    1743         **kwargs,
#    1744     )
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/distributions.py:937, in _DistributionPlotter.plot_univariate_density(self, multiple, common_norm, common_grid, warn_singular, fill, color, legend, estimate_kws, **plot_kws)
#     934 log_scale = self._log_scaled(self.data_variable)
#     936 # Do the computation
# --> 937 densities = self._compute_univariate_density(
#     938     self.data_variable,
#     939     common_norm,
#     940     common_grid,
#     941     estimate_kws,
#     942     log_scale,
#     943     warn_singular,
#     944 )
#     946 # Adjust densities based on the `multiple` rule
#     947 densities, baselines = self._resolve_multiple(densities, multiple)
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/distributions.py:349, in _DistributionPlotter._compute_univariate_density(self, data_variable, common_norm, common_grid, estimate_kws, log_scale, warn_singular)
#     345 try:
#     346     if not singular:
#     347         # Convoluted approach needed because numerical failures
#     348         # can manifest in a few different ways.
# --> 349         density, support = estimator(observations, weights=weights)
#     350 except np.linalg.LinAlgError:
#     351     singular = True
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/_statistics.py:192, in KDE.__call__(self, x1, x2, weights)
#     190 """Fit and evaluate on univariate or bivariate data."""
#     191 if x2 is None:
# --> 192     return self._eval_univariate(x1, weights)
#     193 else:
#     194     return self._eval_bivariate(x1, x2, weights)
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/_statistics.py:151, in KDE._eval_univariate(self, x, weights)
#     149 support = self.support
#     150 if support is None:
# --> 151     support = self.define_support(x, cache=False)
#     153 kde = self._fit(x, weights)
#     155 if self.cumulative:
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/_statistics.py:127, in KDE.define_support(self, x1, x2, weights, cache)
#     125 """Create the evaluation grid for a given data set."""
#     126 if x2 is None:
# --> 127     support = self._define_support_univariate(x1, weights)
#     128 else:
#     129     support = self._define_support_bivariate(x1, x2, weights)
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/_statistics.py:99, in KDE._define_support_univariate(self, x, weights)
#      97 def _define_support_univariate(self, x, weights):
#      98     """Create a 1D grid of evaluation points."""
# ---> 99     kde = self._fit(x, weights)
#     100     bw = np.sqrt(kde.covariance.squeeze())
#     101     grid = self._define_support_grid(
#     102         x, bw, self.cut, self.clip, self.gridsize
#     103     )
#
# File /opt/homebrew/lib/python3.10/site-packages/seaborn/_statistics.py:142, in KDE._fit(self, fit_data, weights)
#     139 if weights is not None:
#     140     fit_kws["weights"] = weights
# --> 142 kde = gaussian_kde(fit_data, **fit_kws)
#     143 kde.set_bandwidth(kde.factor * self.bw_adjust)
#     145 return kde
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/stats/_kde.py:207, in gaussian_kde.__init__(self, dataset, bw_method, weights)
#     204         raise ValueError("`weights` input should be of length n")
#     205     self._neff = 1/sum(self._weights**2)
# --> 207 self.set_bandwidth(bw_method=bw_method)
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/stats/_kde.py:555, in gaussian_kde.set_bandwidth(self, bw_method)
#     551     msg = "`bw_method` should be 'scott', 'silverman', a scalar " \
#     552           "or a callable."
#     553     raise ValueError(msg)
# --> 555 self._compute_covariance()
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/stats/_kde.py:567, in gaussian_kde._compute_covariance(self)
#     563 if not hasattr(self, '_data_inv_cov'):
#     564     self._data_covariance = atleast_2d(cov(self.dataset, rowvar=1,
#     565                                        bias=False,
#     566                                        aweights=self.weights))
# --> 567     self._data_inv_cov = linalg.inv(self._data_covariance)
#     569 self.covariance = self._data_covariance * self.factor**2
#     570 self.inv_cov = self._data_inv_cov / self.factor**2
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/linalg/_basic.py:927, in inv(a, overwrite_a, check_finite)
#     888 def inv(a, overwrite_a=False, check_finite=True):
#     889     """
#     890     Compute the inverse of a matrix.
#     891
#    (...)
#     925
#     926     """
# --> 927     a1 = _asarray_validated(a, check_finite=check_finite)
#     928     if len(a1.shape) != 2 or a1.shape[0] != a1.shape[1]:
#     929         raise ValueError('expected square matrix')
#
# File /opt/homebrew/lib/python3.10/site-packages/scipy/_lib/_util.py:287, in _asarray_validated(a, check_finite, sparse_ok, objects_ok, mask_ok, as_inexact)
#     285         raise ValueError('masked arrays are not supported')
#     286 toarray = np.asarray_chkfinite if check_finite else np.asarray
# --> 287 a = toarray(a)
#     288 if not objects_ok:
#     289     if a.dtype is np.dtype('O'):
#
# File /opt/homebrew/lib/python3.10/site-packages/numpy/lib/function_base.py:627, in asarray_chkfinite(a, dtype, order)
#     625 a = asarray(a, dtype=dtype, order=order)
#     626 if a.dtype.char in typecodes['AllFloat'] and not np.isfinite(a).all():
# --> 627     raise ValueError(
#     628         "array must not contain infs or NaNs")
#     629 return a
#
# ValueError: array must not contain infs or NaNs

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df[df['pk']==7], hue='sk', vars=['exchange', 'attack'], palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.pairplot(data=df, hue='pk', vars=['exchange', 'attack'], palette='crest')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.jointplot(data=df, x='exchange', y='attack', hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.scatterplot(data=df, x='exchange', y='attack', hue='sk', palette='flare')
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.kdeplot(
   data=df, x="attack", hue="sk",
   fill=True, common_norm=False, palette="flare",
   alpha=.5, linewidth=0, log_scale=True
)
gfg.set(title="Attack Time vs Private Key Length", xlabel="Attack Time (ms)")
plt.show()

# %%
sns.set_theme(style="whitegrid")
gfg = sns.kdeplot(
   data=df[df['group'] == 'S16'], x="guesses", hue="sk",
   fill=True, common_norm=False, palette="flare",
   alpha=.5, linewidth=0, log_scale=True
)
gfg.set(title="Guesses vs Private Key Length", xlabel="Guesses")
plt.show()

# %%
sns.set_theme(style="whitegrid")
df2 = df
gfg = sns.kdeplot(
   data=df2, x="attack", hue="pk",
   fill=True, common_norm=False, palette="crest",
   alpha=.5, linewidth=0, log_scale=True
)
gfg.set(title="Attack Time vs Public Key Length", xlabel="Attack Time (ms)")
plt.show()

# %%
# heatmap comparing sk and pk effects on attack time
sns.set_theme(style="whitegrid")
df['efficiency'] = df['attack'] / df['exchange']
g = sns.JointGrid(data=df, x="pk", y="sk")
g.plot_joint(sns.scatterplot, c=df["efficiency"], size=df["attack"], sizes=(30,1200), palette="flare", alpha=.6, legend=False)
g.plot_marginals(sns.histplot, color="m", kde=True)
plt.show()

# %%
# on the same axes, plot the attack time vs exchange time
sns.set_theme(style="whitegrid")
g = sns.JointGrid(data=df, x="efficiency", y="sk")
g.plot_joint(sns.scatterplot, c=df["efficiency"], size=df["attack"], sizes=(30,1200), palette="flare", alpha=.6, legend=False)
g.plot_marginals(sns.histplot, color="m", kde=True)
plt.show()
